# %%
a=3
b=5
print(f'sum of {a} and {b} is {a+b} ')
# Out:
# sum of 3 and 5 is 8

# %%
a={"red","green","blue"}

# %%
a
# Out:
# {'blue', 'green', 'red'}

# %%
type(a)
# Out:
# set

# %%
my_file=open("C:\\pythonTraining\\pythonfordatascience_edx\\word_cloud\\98-1.txt","r+",encoding="utf8")

# %%
print(my_file.readlines())
# Out:
# ['\ufeffThe Project Gutenberg EBook of A Tale of Two Cities, by Charles Dickens\n', '\n', 'This eBook is for the use of anyone anywhere at no cost and with\n', 'almost no restrictions whatsoever.  You may copy it, give it away or\n', 're-use it under the terms of the Project Gutenberg License included\n', 'with this eBook or online at www.gutenberg.org\n', '\n', '\n', 'Title: A Tale of Two Cities\n', '       A Story of the French Revolution\n', '\n', 'Author: Charles Dickens\n', '\n', 'Release Date: January, 1994 [EBook #98]\n', 'Posting Date: November 28, 2009\n', 'Last Updated: September 25, 2016\n', '\n', 'Language: English\n', '\n', 'Character set encoding: UTF-8\n', '\n', '*** START OF THIS PROJECT GUTENBERG EBOOK A TALE OF TWO CITIES ***\n', '\n', '\n', '\n', '\n', 'Produced by Judith Boss\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'A TALE OF TWO CITIES\n', '\n', 'A STORY OF THE FRENCH REVOLUTION\n', '\n', 'By Charles Dickens\n', '\n', '\n', 'CONTENTS\n', '\n', '\n', '
# ...

# %%
alist=["this is a test","project gutenber babe where is my password","my name is gunjan"]

# %%
words={}
for word in my_file:
    a=word.split(" ")
    if a not in words:
        words[a] = 1
    else:
        words[a] += 1
    print(words)

# %%
ert={"a":2,"b":2}
print(ert)
# Out:
# {'a': 2, 'b': 2}

# %%
ert[a]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-f3ffd838612f> in <module>()
# ----> 1 ert[a]
#
# TypeError: unhashable type: 'list'
